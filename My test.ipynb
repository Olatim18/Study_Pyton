# %% [markdown]
#  как подключить учетную запись IBM Watson studio к вашей учетной записи github в Watson studio, перейдите к настройкам профиля на вкладке интеграции, посетите ссылку для создания токена личного доступа github, предоставив описательное имя для токена и выберите область репо, затем сгенерируйте токен, скопируйте токен, возвращаемый к настройкам интеграции github, и вставьте токен, который проверяется при сохранении его в настройках профиля, теперь перейдите к вашим проектам, которые вы включаете интеграцию github на уровне проекта на просто прокрутите вниз и вставьте существующий URL-адрес репозитория github после проверки URL-адреса нажмите кнопку connect перейдите на вкладку активов и откройте блокнот, который вы хотите опубликовать,
# Воспроизведите видео, начиная с :1:14, и следуйте текстовым инструкциям1:14
# обратите внимание, что эта записная книжка имеет учетные данные, замененные на X, это лучшая практика для удаления или замены учетных данных перед публикацией в github, чтобы эта записная книжка была готова к публикации, вы можете предоставить целевой путь вместе с сообщением фиксации, у вас также есть возможность публиковать содержимое без скрытого кода, что означает, что любые ячейки в записной книжке, которые начинались со скрытым комментарием ячейки не будет опубликован, когда вы готовы нажать кнопку опубликовать сообщение сообщает вам, что блокнот был опубликован успешно, и предоставляет ссылки на блокнот, репозиторий в фиксации, давайте посмотрим на коммиты, чтобы есть фиксация и вы можете перейти в репозиторий, чтобы увидеть блокнот публикации, наконец, вы можете опубликовать как суть, просто еще один способ поделиться своей работой над github, каждый gist - это репозиторий git, поэтому его можно разветвить и клонировать, есть два типа gists public и secrete, если вы начнете с секретным gist вы можете преобразовать его в публичный gist позже, и снова у вас есть возможность удалить скрытые ячейки , так что это основы интеграции Watson Studios github
